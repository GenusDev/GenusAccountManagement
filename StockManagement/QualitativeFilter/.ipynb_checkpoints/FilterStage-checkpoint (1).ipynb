# %%
#data management libraries
import requests
from lxml import html
import urllib
import webbrowser
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import glob, os
from os import path
import xlrd
import json
import time

#data libaries
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
import pandas as pd
import pandas_datareader.data as web

# %% [markdown]
# # Classes
#
# ## - CompanyInfo -
# ### Attributes:
#     - all the company info outputs
#     - relevant search info
#         - like how many queries it took to find the page
#         - html contents
#         - last updated
# ### - Methods -
#     - log my wikiInfo to a separate pickle
#     - update dataframe and save to a pickle
#
#
# ## - AnalyticalSession -
# ### Attributes:
#     - date of analysis
#     - outputs -
#         stocks suggested
#     - Risk tolerance
# ### Methods
#     - Run various kinds of analysis
#     - Run log comments
#
#
# ## - Portfolio -
# ### Attributes:
#     - current make up of portfolio
#     - proposed make up of portfolio
#     - earnings
#     - risk level
# ### Methods
#     - show attributes
#     - pull portfolio data
#
#
# # Program Interface
#
# - Portfolio is the main object interacted with in the interface
# - Can deploy an analytical session (might be done at particular intervals eventually)
# - an analytical session summarizes a broad set of company analytics, though a company's analysis can also be a separate object

# %%
#Data Management Module

import wikipedia
import bs4
from bs4 import BeautifulSoup

soup = BeautifulSoup(TSLA.html(), 'html.parser')
   

class StockData:

    def __init__(self):        
        self.date = datetime.date.today().strftime('%Y%m%d')
        
    def pullAllTickerSymbols(self):    
        StockListDict = pullAllStockTickers()
        self.data = self.reIndexBasedOn(Symbol)
        return reindexedStockList
    
        def pullAllStockTickers():
            
        def reIndexBasedOn(Symbol):
                      
        
    def updateStockDatawithWikiPastPickle(self,dateSpecified):
        mostRecentWikiData = loadpickle(dateSpecified)
        StockDataupdatedWithWikiData = joinBasedOnSymbol(mostRecentData)
        self.data = StockDataupdatedWithWikiData
        return StockDataupdatedWithWikiData
    
        def loadpickle(dateSpecified):
        
        def joinBasedOnSymbol(mostRecentData):
            self.data 
            
    def scrapeWikiData(self):
        
        for each stock 
            make a CompanyProfile instance
            then run company profiles method for grabing company data about that company
            save the data to a wiki specific pickle 
        
        when all stocks have run then run update data withpickle 
        
        def saveStocktoPickle(CompanyProfile):
        
        

class CompanyProfile:  
    
    def __init__(self,CompanyData):        
        self.name = CompanyData['Name']

        pullInIPOPickle = open ('IPODates.pickle', 'wb')
        pickle.dump(start,pullInIPOPickle)
        fileHandler.close()

    def logIPOData(IPOData):
        fileWrite = open('IPODates.pickle', 'wb')
        pickle.dump(IPOData, fileWrite)
        fileWrite.close()

    def loadIPOPickleData():
        IPODatesPickleLatestasFile = open('IPODates.pickle', 'rb')
        IPODatesPickleLatest = pickle.load(IPODatesPickleLatestasFile)
        IPODatesPickleLatestasFile.close() 
        return IPODatesPickleLatest

    def MetricFunction(x):
        print(x)
        currentYear = int(dt.date.today().year)
        xf = float(x)
        yearsAround = cy - xf + 1
        metric = 1.5 / yearsAround
        return metric

    def yearLookUpandRecord(symbol):

        driver = PDA.setDriverUp()

        print(symbol)
    #     try:
        YearandNumbOfWorkers = PDA.StockInfoGrab(symbol, driver)
        print (YearandNumbOfWorkers)

        IPODatesPickleLatest = loadIPOPickleData()

        IPODatesPickleLatest[symbol] = {
            "symbol": symbol,
            "employees": YearandNumbOfWorkers['Employees'],
            'IPODate': YearandNumbOfWorkers['IPODate'],
            'dateLogged': datetime.date.today().strftime('%Y%m%d')
        } 

        logIPOData(IPODatesPickleLatest)

        return YearandNumbOfWorkers

    #     except:
    #         pass




    def ScrapeandSaveData(): 
        IPODatesPickleLatest = loadIPOPickleData()
        print(IPODatesPickleLatest.keys())

        for eachTicker in data.Symbol[0:10]:
            if eachTicker not in IPODatesPickleLatest.keys():
                #add in if statement to look up to see if there is already data available in data
                yearLookUpandRecord(eachTicker)
                time.sleep(60)
            else:
                pass



class Analysis:
    
    def filterStocks():
# Out:
#   File "<ipython-input-5-6919a1933f60>", line 22
#     def reIndexBasedOn(Symbol):
#       ^
# IndentationError: expected an indented block

# %%
class CompanyProfile:  
    
    def __init__(self,CompanyData):        
        self.name = CompanyData['Name']

        pullInIPOPickle = open ('IPODates.pickle', 'wb')
        pickle.dump(start,pullInIPOPickle)
        fileHandler.close()

    def logIPOData(IPOData):
        fileWrite = open('IPODates.pickle', 'wb')
        pickle.dump(IPOData, fileWrite)
        fileWrite.close()

    def loadIPOPickleData():
        IPODatesPickleLatestasFile = open('IPODates.pickle', 'rb')
        IPODatesPickleLatest = pickle.load(IPODatesPickleLatestasFile)
        IPODatesPickleLatestasFile.close() 
        return IPODatesPickleLatest

    def MetricFunction(x):
        print(x)
        currentYear = int(dt.date.today().year)
        xf = float(x)
        yearsAround = cy - xf + 1
        metric = 1.5 / yearsAround
        return metric

    def yearLookUpandRecord(symbol):

        driver = PDA.setDriverUp()

        print(symbol)
    #     try:
        YearandNumbOfWorkers = PDA.StockInfoGrab(symbol, driver)
        print (YearandNumbOfWorkers)

        IPODatesPickleLatest = loadIPOPickleData()

        IPODatesPickleLatest[symbol] = {
            "symbol": symbol,
            "employees": YearandNumbOfWorkers['Employees'],
            'IPODate': YearandNumbOfWorkers['IPODate'],
            'dateLogged': datetime.date.today().strftime('%Y%m%d')
        } 

        logIPOData(IPODatesPickleLatest)

        return YearandNumbOfWorkers

    #     except:
    #         pass




    def ScrapeandSaveData(): 
        IPODatesPickleLatest = loadIPOPickleData()
        print(IPODatesPickleLatest.keys())

        for eachTicker in data.Symbol[0:10]:
            if eachTicker not in IPODatesPickleLatest.keys():
                #add in if statement to look up to see if there is already data available in data
                yearLookUpandRecord(eachTicker)
                time.sleep(60)
            else:
                pass
# Out:
# <Response [200]>

# %%
TSLA =  CompanyProfile(TslaCompanyData)
TSLA.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d73063ec2def> in <module>()
# ----> 1 from twill.commands import *
#
# ModuleNotFoundError: No module named 'twill'

# %%
import PullTickers
AllStockTickerDataSymbolsandBasics = PullTickers.pullAllStockTickers()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-e3cf303996bf> in <module>()
# ----> 1 import PullTickers
#       2 AllStockTickerDataSymbolsandBasics = PullTickers.pullAllStockTickers()
#
# ModuleNotFoundError: No module named 'PullTickers'
