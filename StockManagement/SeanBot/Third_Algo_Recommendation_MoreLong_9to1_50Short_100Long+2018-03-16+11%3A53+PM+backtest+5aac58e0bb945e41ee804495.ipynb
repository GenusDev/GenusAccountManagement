# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5aac58e0bb945e41ee804495')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-06-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>11</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>10.8%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>10.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.7%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.71</td>
#     </tr>
#     <tr>
# ...
